# %%
import pandas as pd 
import random
df = pd.read_csv("poems.csv")
df
# Out:
#     Index                      Author  \
# 0       1         Ralph Waldo Emerson
# 1       2          Robert A. Heinlein
# 2       3             Abraham Lincoln
# 3       4             Chuck Palahniuk
# 4       5            Ernest Hemingway
# 5       6              Mahatma Gandhi
# 6       7                Albert Camus
# 7       8             Stephen Chbosky
# 8       9  Henry Wadsworth Longfellow
# 9      10              Dalai Lama XIV
# 10     11                  John Lenon
# 11     12               J.R.R Toliken
# 12     13                  Tom Bodett
# 13     14              Audrey Hepburn
# 14     15           Charles M. Schulz
# 15     16             Stephen Chbosky
# 16     17              David Levithan
# 17     18        Jonathan Safran Foer
# 18     19           Leonardo da Vinci
# 19     20            Dorothy Thompson
# 20     21               Henry Rollins
# 21     22               George Elliot
# 22     23              Tabitha Suzuma
# 23     24           Margaret Mitchell
# 24     25                  John Lenon
# 25     26            Arthur C. Clarke
# 26     27          Christopher Morley
# 27     28              Norman Cousins
# 28     29                  Bob Marley
# 29     30           Leonardo Da Vinci
#
#                                                 Quote  Class
# 0   For every minute you are angry you lose sixty ...      1
# 1   Love is that condition in which the happiness ...      1
# 2   Folks are usually about as happy as they make ...      1
# 3   It's so hard to forget pain but it's even hard...      1
# 4   Happiness in intelligent people is the rarest ...      1
# 5   Happiness is when what you think what you say ...      1
# 6   You will never be happy if you continue to sea...      1
# 7   There's nothing like deep breaths after laughi...      1
# 8   Every man has his secret sorrows which the wor...      1
# 9   Happiness is not something ready made. It come...      1
# 10  Count your age by friends not years. Count you...      1
# 11  If more of us valued food and cheer and song a...      1
# 12  They say a person needs just three things to b...      1
# 13  The most important thing is to enjoy your life...      1
# 14                          Happiness is a warm puppy      1
# 15  Things change. And friends leave. Life doesn't...      0
# 16  Breathing is hard. When you cry so much it mak...      0
# 17  You cannot protect yourself from sadness witho...      0
# 18   Tears come from the heart and not from the brain      0
# 19  To have felt too much is to end in feeling not...      0
# 20  It's sad when someone you know becomes someone...      0
# 21  It will never rain roses: when we want to have...      0
# 22  As the light begins to intensify so does my mi...      0
# 23  Life's under no obligation to give us what we ...      0
# 24  One thing you can't hide — is when you're crip...      0
# 25  Two possibilities exist: either we are alone i...      0
# 26  Heavy hearts like heavy clouds in the sky are ...      0
# 27  Death is not the greatest loss in life. The gr...      0
# 28  The good times of today are the sad thoughts o...      0
# 29   Tears come from the heart and not from the brain      0

# %%
def getPoem(mood):
    index = 0
    if(mood == 1):
        i = random.randint(1,16)
        for index, row in df.iterrows():
            if(i==index):
                print(row["Author"] + " - " + row["Quote"])
    elif(mood == 0):
        i = random.randint(16,31)
        for index, row in df.iterrows():
            if(i==index):
                print(row["Author"] + " - " + row["Quote"])
    
getPoem(0)
# Out:
# George Elliot - It will never rain roses: when we want to have more roses we must plant more roses
